# %% [markdown]
# # 🐍 Python — String Methods: Теория и 20 заданий (без решений)
# *Создано: 2025-10-10 10:30*
#
# ## Краткая теория
# - Методы не изменяют исходную строку, а возвращают новую.
# - Категории: проверка (`is*`), поиск/подсчёт (`find`, `rfind`, `count`), форматирование регистра/выравнивания (`upper`, `lower`, `title`, `center`, `ljust`, `rjust`, `zfill`),
#   разбиение/соединение (`split`, `rsplit`, `splitlines`, `join`, `partition`, `rpartition`),
#   замена/перевод (`replace`, `maketrans`, `translate`),
#   обрезка пробелов (`strip`, `lstrip`, `rstrip`), кодирование (`encode`), табы (`expandtabs`).

# %% [markdown]
# ### Задание 1. capitalize/title
# Пусть s='hello world'. Выведите s.capitalize() и s.title().

# %%
# Ваш код здесь
s = "hello world!"
print(f"Her we can see method 'capitalize' '{s.capitalize()}'", f"Her we can see method 'title' '{s.title()}'", sep = "\n")
# Out:
# Her we can see method 'capitalize' 'Hello world!'
# Her we can see method 'title' 'Hello World!'

# %% [markdown]
# ### Задание 2. swapcase/upper/lower
# Пусть s='PyThOn'. Выведите s.swapcase(), s.upper(), s.lower().

# %%
# Ваш код здесь
s = "PyThOn"
print(s.swapcase(),s.upper(),s.lower())
# Out:
# pYtHoN PYTHON python

# %% [markdown]
# ### Задание 3. strip/lstrip/rstrip
# Пусть s='  text  '. Удалите пробелы: слева, справа и по краям.

# %%
# Ваш код здесь
s = "_text_"
print(s.strip("_"), s.lstrip("_"), s.rstrip("_"), sep="\n")
# Out:
# text
# text_
# _text

# %% [markdown]
# ### Задание 4. center/ljust/rjust
# Пусть s='hi'. Выведите центр/лево/право в ширине 6, заполните '-'.

# %%
# Ваш код здесь
s = "hi"
print(s.center(6,"-"), s.ljust(6,"-"), s.rjust(6,"-"), sep = "\n")
# Out:
# --hi--
# hi----
# ----hi

# %% [markdown]
# ### Задание 5. zfill
# Пусть num='73'. Выведите num.zfill(5).

# %%
# Ваш код здесь
num = "73"
print(num.zfill(5))
# Out:
# 00073

# %% [markdown]
# ### Задание 6. find/rfind
# Пусть s='banana'. Выведите s.find('an') и s.rfind('an').

# %%
# Ваш код здесь
s = "banana"
print(s.find("an"), s.rfind("an"))
# Out:
# 1 3

# %% [markdown]
# ### Задание 7. count
# Пусть s='bananana'. Подсчитайте количество 'ana'.

# %%
# Ваш код здесь
s = "bananana"
print(s.count("ana"))
# Out:
# 2

# %% [markdown]
# ### Задание 8. startswith/endswith
# Пусть s='hello.py'. Проверьте s.startswith('he') и s.endswith('.py').

# %%
# Ваш код здесь
s = "hello.py"
print(s.startswith("he"), s.endswith("py"))
# Out:
# True True

# %% [markdown]
# ### Задание 9. split/rsplit
# Пусть s='a,b,c,d'. Выведите split(',') и rsplit(',', 1).

# %%
# Ваш код здесь
s = "a,b,c,d"
print(s.split(","), s.rsplit(",",1), sep = "\n")
# Out:
# ['a', 'b', 'c', 'd']
# ['a,b,c', 'd']

# %% [markdown]
# ### Задание 10. splitlines
# Пусть s='one\ntwo\r\nthree'. Выведите список строк через splitlines().

# %%
# Ваш код здесь
s = "one\ntwo\r\nthree"
print(s.splitlines("\\n"))
# Out:
# ['one\n', 'two\r\n', 'three']

# %% [markdown]
# ### Задание 11. join
# Пусть words=['red','green','blue']. Получите строку 'red|green|blue' через join.

# %%
# Ваш код здесь
words = ['red','green','blue']
print("|".join(words))
# Out:
# red|green|blue

# %% [markdown]
# ### Задание 12. replace
# Пусть s='hello world world'. Замените только первое 'world' на 'python'.

# %%
# Ваш код здесь
s = "hello world world"
print(s.replace("world","python", 1))
# Out:
# hello python world

# %% [markdown]
# ### Задание 13. partition/rpartition
# Пусть s='key=value=value2'. Выведите partition('=') и rpartition('=') и поясните разницу в комментарии.

# %%
# Ваш код здесь
s = "key = value = value2"
print(f"In first one it's starts in the left side: {s.partition("=")} ", f"In the second one it's starst in the right side: {s.rpartition("=")}", sep = "\n")
# Out:
# In first one it's starts in the left side: ('key ', '=', ' value = value2')
# In the second one it's starst in the right side: ('key = value ', '=', ' value2')

# %% [markdown]
# ### Задание 14. index/rindex
# Пусть s='bananas'. Выведите индекс первого 'na' и последнего 'na' методами index/rindex.

# %%
# Ваш код здесь
s = "bananas"
print(f"Firsts index 'na' : {s.index("na")}", f"Second index 'na' : {s.rindex("na")}", sep = "\n")
# Out:
# Firsts index 'na' : 2
# Second index 'na' : 4

# %% [markdown]
# ### Задание 15. isalpha/isdigit/isalnum
# Проверьте для 'abc', '123', 'abc123' соответствующие булевы методы.

# %%
# Ваш код здесь
a, b, c = "abc", "123", "abc123"
print(a.isalpha(), b.isdigit(), c.isalnum())
# Out:
# True True True

# %% [markdown]
# ### Задание 16. isspace
# Проверьте '   ' и '\t\n' на isspace().

# %%
# Ваш код здесь
a, b = " ", "\t\n"
print(a.isspace(), b.isspace())
# Out:
# True True

# %% [markdown]
# ### Задание 17. istitle/isupper/islower
# Проверьте 'Hello World', 'HELLO', 'hello'.

# %%
# Ваш код здесь
a, b , c = "Hello World", "HELLO", "hello"
print(a.istitle(), b.isupper(), c.islower())
# Out:
# True True True

# %% [markdown]
# ### Задание 18. isidentifier
# Проверьте допустимость идентификаторов: 'name', '2name', 'my-var', '_ok'.

# %%
# Ваш код здесь
a, b , c, d = "name", "2name", "my-var", "_ok"
print(a.isidentifier(),b.isidentifier(),c.isidentifier(), d.isidentifier())
# Out:
# True False False True

# %% [markdown]
# ### Задание 19. maketrans/translate
# Создайте таблицу замен a->4, e->3, i->1, o->0; примените к 'validation'.

# %%
# Ваш код здесь
nam = "validation"
new_nam = nam.maketrans("aeio", "4310")
print(nam.translate(new_nam))
# Out:
# v4l1d4t10n

# %% [markdown]
# ### Задание 20. encode/expandtabs
# Пусть s='A\tB\tC'. Выведите s.expandtabs(4) и s.encode('utf-8').

# %%
# Ваш код здесь
s = "A\tB\tc"
print(s.expandtabs(4), s.encode("utf-8"), sep = "\n")
# Out:
# A   B   c
# b'A\tB\tc'
