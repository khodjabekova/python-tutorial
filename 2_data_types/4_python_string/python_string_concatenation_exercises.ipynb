# %% [markdown]
# # 🐍 Python — String Concatenation: Теория и 20 заданий (без решений)
# *Создано: 2025-10-10 10:24*
#
# ## Краткая теория
# - Конкатенация строк: `a + b`.
# - Добавление пробелов/символов: `a + ' ' + b`, `a + '-' + b`.
# - Повтор строк: `s * n`.
# - Смешивание типов требует преобразования: `str(x)` или форматирования `f'...'`, `'{}'.format(...)`.
# - Для списков строк используйте `''.join(list_of_str)` — эффективно и удобно.
#
# ### Блок «Практика форматирования»
# В конце заданий есть две задачи на f-строки и `.format()` — соберите те же данные разными способами.

# %% [markdown]
# ### Задание 1. Базовая конкатенация
# Пусть a = 'Hello', b = 'World'. Объедините их без пробела и выведите.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 2. Пробел между словами
# Пусть a = 'Hello', b = 'World'. Объедините их с пробелом между ними.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 3. Добавить символ
# Пусть a = 'abc', b = 'def'. Объедините в 'abc-def'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 4. Многократная конкатенация
# Пусть s = 'ha'. Получите строку 'hahaha' с помощью оператора * или +.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 5. Конкатенация и числа (ошибка)
# Пусть x = 5. Покажите, что 'Value: ' + x вызывает ошибку. Исправьте (через str(), запятые, f-string).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 6. Сборка сообщения
# Пусть name='Alice', lang='Python'. Получите строку 'Alice learns Python' тремя способами (+' ', запяты, f-string).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 7. Конкатенация в цикле
# Соберите строку из символов списка ['P','y','t','h','o','n'] в одно слово с помощью конкатенации и выведите.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 8. join как альтернатива
# То же самое, но используйте ''.join([...]). Объясните в комментарии, почему это предпочтительно для больших списков.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 9. Разделитель
# Пусть words=['red','green','blue']. Получите 'red, green, blue' (обратите внимание на пробел после запятой).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 10. Пути файлов
# Пусть folder='home', user='alice', file='notes.txt'. Соберите 'home/alice/notes.txt'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 11. Многострочная сборка
# Соберите строку 'Line1\nLine2\nLine3' из частей с помощью конкатенации.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 12. Шаблон с повтором
# Пусть word='hi'. Получите строку 'hi --- hi --- hi' (используйте повтор и конкатенацию).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 13. Лишние пробелы
# Пусть a=' Hello ', b='World '. Соберите 'Hello World' (предварительно обрежьте пробелы по краям).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 14. Вставка чисел
# Пусть day=7, month='April'. Соберите строку 'Today is 7 April' тремя способами.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 15. Таблица
# Соберите заголовок таблицы из названий столбцов с табами: 'name\tage\tcity'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 16. Счётчик
# Для n=3 соберите строку '1, 2, 3' только конкатенацией (+) и преобразованием в str().

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 17. Склеивание срезов
# Пусть s='Concatenation'. Соберите 'Concat' + 'enation' из срезов исходной строки.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 18. Ограничитель начала/конца
# Пусть core='content'. Соберите '[content]' с помощью конкатенации.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 19. Форматирование: f-string
# Пусть first='Ada', last='Lovelace', year=1843. Соберите: 'Ada Lovelace, 1843' с f-строкой.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 20. Форматирование: format()
# То же самое задание, но с методом .format().

# %%
# Ваш код здесь
