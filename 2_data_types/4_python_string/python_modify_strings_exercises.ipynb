# %% [markdown]
# # 🐍 Python — Modify Strings: Теория и 20 заданий (без решений)
# *Создано: 2025-10-10 10:21*
#
# ## Краткая теория
# - Регистр: `upper()`, `lower()`, `casefold()`.
# - Пробелы: `strip()`, `lstrip()`, `rstrip()`; `strip(chars)` удаляет указанные символы по краям.
# - Замены: `replace(old, new[, count])`.
# - Разбиение: `split(sep=None, maxsplit=-1)`, `splitlines()`.
# - Форматирование/выравнивание: `center(width[, fillchar])`, `ljust`, `rjust`; `startswith`, `endswith`.
# - Методы можно **комбинировать**: `s.strip().lower().replace(...)`.

# %% [markdown]
# ### Задание 1. upper()
# Пусть s = 'Welcome'. Выведите строку в ВЕРХНЕМ регистре.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 2. lower()
# Пусть s = 'HeLLo'. Выведите строку в нижнем регистре.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 3. strip()
# Пусть s = '  hello  '. Удалите пробелы по краям и выведите результат.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 4. replace() базово
# Пусть s = 'banana'. Замените все 'a' на 'o'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 5. replace() количество
# Пусть s = 'aaaaa'. Замените только первые две 'a' на 'x'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 6. split() по запятой
# Пусть s = 'a,b,c'. Разбейте строку по ',' и выведите список.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 7. split() и пробелы
# Пусть s = 'one  two   three'. Разбейте по любому числу пробелов с помощью split() без аргументов.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 8. strip()+lower()
# Пусть s = '  HeLLo WoRLD  '. Удалите пробелы по краям и приведите к нижнему регистру.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 9. replace цепочкой
# Пусть s = '2024-10-01'. Замените '-' на '/' и выведите.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 10. split с ограничением
# Пусть s = 'name:John:Doe'. Разбейте по ':' максимум на одно разделение (получите 2 элемента).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 11. lstrip()/rstrip()
# Пусть s = '---hello***'. Удалите ведущие '-' и затем удалите хвостовые '*'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 12. strip символов
# Пусть s = '...hello...'. Удалите точки по краям с помощью strip('.')

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 13. replace подстроки
# Пусть s = 'hello world world'. Замените только первое вхождение 'world' на 'python'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 14. splitlines()
# Пусть s = 'line1\nline2\r\nline3'. Разбейте на строки и выведите список.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 15. casefold()
# Пусть s = 'Straße'. Выведите s.casefold() и s.lower() для сравнения.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 16. title()/capitalize()
# Пусть s = 'hello world'. Выведите s.title() и s.capitalize().

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 17. center()/ljust()/rjust()
# Пусть s = 'hi'. Выведите варианты: по центру в ширине 6, слева ширина 6, справа ширина 6, заполняя '-'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 18. startswith()/endswith()
# Пусть s = 'hello.py'. Проверьте начинается ли на 'hello' и оканчивается ли на '.py'.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 19. Практика: очистка
# Пусть s = '  Hello,   world!  '. Получите 'hello, world!' (один пробел после запятой, нижний регистр, без лишних пробелов).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 20. Практика: извлечение
# Пусть s = 'id=12345; name=Alice; role=admin'. Получите список значений ['12345','Alice','admin'].

# %%
# Ваш код здесь
