# %% [markdown]
# # 🐍 Python — Escape Characters: Теория и 20 заданий (без решений)
# *Создано: 2025-10-10 10:28*
#
# ## Краткая теория
# - Escape-последовательность начинается с обратного слеша `\` и задаёт спецсимвол: `\n`, `\t`, `\r`, `\'`, `\"`, `\\` и т.д.
# - Шестнадцатеричные/октальные коды: `\xhh`, `\ooo`.
# - Сырые строки: `r"..."` не интерпретируют `\` как начало escape (кроме закрывающей кавычки). Удобно для путей и regex.
# - Для выводимых фигурных скобок в форматировании используйте удвоение: `{{` и `}}`.

# %% [markdown]
# ### Задание 1. Кавычки в кавычках
# Соберите строку с двойными кавычками внутри двойных: We are the so-called "Vikings" from the north. (используйте экранирование).

# %%
print('We are the so-called "Vikings" from the north')
# Out:
# We are the so-called "Vikings" from the north

# %% [markdown]
# ### Задание 2. Одинарные в одинарных
# Соберите строку: It's fine. — используя одинарные кавычки и экранирование апострофа.

# %%
print("It's fine.")
# Out:
# It's fine.

# %% [markdown]
# ### Задание 3. Обратный слеш
# Выведите строку, содержащую один обратный слеш: \\.

# %%
print('Привет я Юсуф\\')
# Out:
# Привет я Юсуф\

# %% [markdown]
# ### Задание 4. Перенос строки
# Выведите две строки в одной печати: 'Hello' и 'World' на разных строках с помощью \n.

# %%
print('Hello \n World')
# Out:
# Hello
#  World

# %% [markdown]
# ### Задание 5. Табуляция
# Сформируйте строку с табуляцией между словами: 'A\tB\tC'.

# %%
print('A\tB\tC')
# Out:
# A	B	C

# %% [markdown]
# ### Задание 6. Возврат каретки
# Покажите поведение '\r' на примере: 'Hello\rX' и выведите результат.

# %%
print('Hello\rX')
print("Hello\rWorl")
# Out:
# Xello
# Worlo

# %% [markdown]
# ### Задание 7. Backspace
# Покажите поведение '\b' в строке: 'ABC\bD'. Что получится на выводе?

# %%
print('ABC\bD')
# Out:
# ABD

# %% [markdown]
# ### Задание 8. Form feed
# Выведите строку с символом '\f' между словами: 'left\f right'.

# %%
print('left\fright')
# Out:
# leftright

# %% [markdown]
# ### Задание 9. Октавая запись
# Соберите символ заглавной 'A' через октальную запись \101 и выведите.

# %%
print('\101')
# Out:
# A

# %% [markdown]
# ### Задание 10. Шестнадцатеричная запись
# Соберите символ заглавной 'B' через \x42 и выведите.

# %%
print('\x42')
# Out:
# B

# %% [markdown]
# ### Задание 11. Комбинированные экранирования
# Соберите строку: "Path: C:\\new_folder\\file.txt\nDone" и выведите.

# %%
print("Path: C:\\new_folder\\file.txt\\nDone")
# Out:
# Path: C:\new_folder\file.txt\nDone

# %% [markdown]
# ### Задание 12. Сырая строка (raw)
# Создайте raw-строку r"C:\new\path" и обычную "C:\\new\\path". Выведите обе и сравните.

# %%
print(r"C:\new\path")
print("C:\new\path")
# Out:
# C:\new\path
# C:
# ew\path
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User\AppData\Local\Temp\ipykernel_24236\1338036330.py:2: SyntaxWarning: invalid escape sequence '\p'
#   print("C:\new\path")

# %% [markdown]
# ### Задание 13. Кавычки без экранирования
# Покажите альтернативу экранированию: используйте разные кавычки для строки "He said 'Hi'" и 'She said "Hi"'.

# %%
print("He said 'Hi'")
print('She said "Hi"')
# Out:
# He said 'Hi'
# She said "Hi"

# %% [markdown]
# ### Задание 14. Многострочная + экранирование
# Создайте многострочную строку с тройными кавычками, в которой есть табы и кавычки, и выведите.

# %%
print("""Lorem ipsum dolor sit amet consectetur adipiscing elit.
      \tQuisque faucibus ex sapien vitae pellentesque sem placerat. 
      \tIn id cursus mi pretium tellus duis convallis. 
      \tTempus leo eu aenean sed diam urna tempor. 
      Pulvinar vivamus fringilla lacus nec metus bibendum egestas. 
      Iaculis massa nisl malesuada lacinia integer nunc posuere. 
      Ut hendrerit semper vel class aptent taciti sociosqu. 
      Ad litora torquent per conubia nostra inceptos himenaeos.""")
# Out:
# Lorem ipsum dolor sit amet consectetur adipiscing elit.
#       	Quisque faucibus ex sapien vitae pellentesque sem placerat.
#       	In id cursus mi pretium tellus duis convallis.
#       	Tempus leo eu aenean sed diam urna tempor.
#       Pulvinar vivamus fringilla lacus nec metus bibendum egestas.
#       Iaculis massa nisl malesuada lacinia integer nunc posuere.
#       Ut hendrerit semper vel class aptent taciti sociosqu.
#       Ad litora torquent per conubia nostra inceptos himenaeos.

# %% [markdown]
# ### Задание 15. Экранирование фигурных скобок
# Соберите строку с буквальными '{' и '}' и текстом внутри: '{escaped}'.

# %%
print('{escaped}')
# Out:
# {escaped}

# %% [markdown]
# ### Задание 16. ASCII-«таблица»
# Сформируйте три строки с колонками, разделёнными табами: 'col1\tcol2\tcol3', '1\t2\t3', 'a\tb\tc' и выведите одной печатью с \n.

# %%
print('col1\tcol2\tcol3\n1\t2\t3\na\tb\tc')
# Out:
# col1	col2	col3
# 1	2	3
# a	b	c

# %% [markdown]
# ### Задание 17. Литерлы в f-строках
# Покажите, как вывести литерал обратного слеша в f-строке: f"\\".

# %%
print(f'\\')
# Out:
# \

# %% [markdown]
# ### Задание 18. Смешанные кавычки и слеши
# Соберите: "He said: \"C:\\Program Files\\\"".

# %%
print('He said: "C:\\Program Files\\"')
# Out:
# He said: "C:\Program Files\"

# %% [markdown]
# ### Задание 19. Эмодзи через hex
# Соберите символ '©' через \u00A9 и выведите. (подсказка: это не escape из таблицы выше, но тоже escape-последовательность Python)

# %%
print('\U0001F680')
# Out:
# 🚀

# %% [markdown]
# ### Задание 20. Пути без ошибок
# Соберите Windows-путь к файлу: r"D:\docs\notes.txt" (raw-строка) и обычную строку "D:\\docs\\notes.txt". Выведите обе.

# %%
print(r"D:\docs\notes.txt")
print("D:\\docs\\notes.txt")
# Out:
# D:\docs\notes.txt
# D:\docs\notes.txt
