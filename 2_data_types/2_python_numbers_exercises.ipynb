# %% [markdown]
# # 🐍 Python Numbers
# ## Краткая теория
# - Числовые типы: **int**, **float**, **complex**.
# - Проверка типа: `type(x)`.
# - Преобразование типов: `int()`, `float()`, `complex()` (нельзя преобразовать `complex` к `int/float`).
# - Научная запись: `1e3 == 1000.0`.
# - Модуль `random`: `randint`, `randrange`, `uniform`, `random`.
# - Полезные функции: `round`, `abs`, `pow`, `math.sqrt`, `math.floor`, `math.ceil`.
# - Комплексные числа: `a+bj`, `z.real`, `z.imag`, `abs(z)`.

# %% [markdown]
# ### Задание 1. Определение типов
# Создайте `x = 1` (int), `y = 2.8` (float), `z = 1j` (complex) и распечатайте их типы с помощью `type()`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 2. Integers: произвольная длина
# Создайте `a = 1`, `b = 35656222554887711`, `c = -3255522` и выведите их типы.

# %%
a = 1
b = 3565222554887711
c = -3255522
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### Задание 3. Floats: десятичные
# Создайте `x = 1.10`, `y = 1.0`, `z = -35.59` и выведите их типы.

# %%
x = 1.10
y = 1.0
z = -35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ### Задание 4. Floats: научная запись
# Создайте `x = 35e3`, `y = 12E4`, `z = -87.7e100`. Выведите их значения и типы.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 5. Complex: базово
# Создайте `x = 3+5j`, `y = 5j`, `z = -5j` и выведите их типы.

# %%
x = 3+5j
y = 5j
z = -5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# ### Задание 6. Преобразование типов
# Даны `x = 1`, `y = 2.8`, `z = 1j`. Преобразуйте: `a = float(x)`, `b = int(y)`, `c = complex(x)`. Выведите значения и типы.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 7. Запрещённое преобразование
# Попробуйте преобразовать `1j` в `int` или `float`. Зафиксируйте ошибку в комментарии и объясните, почему так нельзя.

# %%
print(int(1j))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(int(1j))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# ### Задание 8. Сложение и умножение
# Пусть `a = 7`, `b = 2.5`. Вычислите `a+b`, `a*b`, выведите типы результата.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 9. Деление и целая часть
# Пусть `a = 7`, `b = 2`. Вычислите `a/b`, `a//b`, `a % b` и выведите их.

# %%
a = 7
b = 2
print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.5
# 3
# 1

# %% [markdown]
# ### Задание 10. Степень и корень
# Используйте `pow(9, 0.5)` и `math.sqrt(9)` для извлечения корня. Сравните результаты.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 11. Округление и модуль
# Продемонстрируйте `round(2.675, 2)` и `abs(-5.3)`. Объясните поведение округления в комментарии.

# %%
print(round(2.675, 2))
print(abs(-5.3))
# Out:
# 2.67
# 5.3

# %% [markdown]
# ### Задание 12. Сравнение чисел
# Сравните `0.1 + 0.2` с `0.3` на равенство. Используйте допуск с `abs((a-b)) < 1e-9`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 13. Случайные целые
# Импортируйте `random` и выведите случайное целое от 1 до 10 включительно (`randrange` или `randint`).

# %%
import random
a = random.randrange(1, 10)
print(a)
# Out:
# 9

# %% [markdown]
# ### Задание 14. Случайные вещественные
# Сгенерируйте вещественное число в диапазоне `[0, 1)` и число в диапазоне `[5, 10)` (используя `random.random()` и `random.uniform()`).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 15. Complex: операции
# Пусть `z1 = 2+3j`, `z2 = 1-4j`. Вычислите `z1+z2`, `z1*z2`, модуль `abs(z1)`.

# %%
z1 = 2+3j
z2 = 1-4j
print(z1+z2)
print(z1*z2)
print(abs(z1))
# Out:
# (3-1j)
# (14-5j)
# 3.605551275463989

# %% [markdown]
# ### Задание 16. Части комплексного
# Для `z = 3-4j` выведите `z.real`, `z.imag` и фазу (угол) через `math.atan2(z.imag, z.real)`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 17. Infinity и NaN
# Используя `float('inf')`, `float('-inf')`, `float('nan')`, покажите их поведение при сравнениях и операциях.

# %%
import math
print(float(36055512754.63989) > float('inf'))
print(float('-inf'))
print(float('nan') > 0)
x = float('nan')
math.isnan(x)
# Out:
# False
# -inf
# False
# True

# %% [markdown]
# ### Задание 18. Форматированный вывод
# Выведите число `pi = 3.1415926535` с точностью до 3 знаков после запятой тремя способами (f-string, `format`, `%`).

# %%
# Ваш код здесь

# %% [markdown]
# ### Задание 19. Парсинг из строки
# Преобразуйте строки `'42'`, `'3.5'`, `'-2'` в числа нужных типов и сложите их.

# %%
a = '42'
b = '3.5'
c = '-2'
a = int(a)
b = float(b)
c = int(c)
print(a + b + c)
# Out:
# 43.5

# %% [markdown]
# ### Задание 20. Мини-калькулятор
# Пусть `a=12`, `b=5`. Выведите сумму, разность, произведение, частное, остаток, степень, целочисленное деление в одной строке через запятую.

# %%
# Ваш код здесь
