# %% [markdown]
# # 🐍 Python: Multiple Assignment

# %% [markdown]
# ## Присваивание нескольким переменным
# **Python** позволяет присваивать значения сразу нескольким переменным в одной строке.
#
# ### 1. Много значений — многим переменным
# ```python
# x, y, z = 'Orange', 'Banana', 'Cherry'
# print(x, y, z)
# ```
# Количество переменных должно **совпадать** с количеством значений.
#
# ### 2. Одно значение — многим переменным
# ```python
# x = y = z = 'Orange'
# print(x, y, z)
# ```
# Все переменные будут указывать на одно и то же значение.
#
# ### 3. Распаковка коллекции (unpacking)
# ```python
# fruits = ['apple', 'banana', 'cherry']
# x, y, z = fruits
# print(x, y, z)
# ```
# Можно использовать `*` для распаковки нескольких элементов:
# ```python
# a, *b = [1, 2, 3, 4]
# print(a)  # 1
# print(b)  # [2, 3, 4]
# ```

# %% [markdown]
# ### Упражнение 1. Три переменные
# Присвойте `'Red'`, `'Green'`, `'Blue'` переменным `r, g, b` и выведите их.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 2. Несоответствие длины
# Что произойдёт при `a, b = 1, 2, 3`? Исправьте ошибку.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 3. Одно значение всем
# Сделайте `x = y = z = 'Python'` и выведите все переменные.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 4. Список фруктов
# Создайте список `['apple', 'banana', 'cherry']` и распакуйте в `a, b, c`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 5. Множественное обновление
# Создайте `a, b = 1, 2` и поменяйте их местами одной строкой.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 6. Частичная распаковка
# С помощью `*` присвойте: `first, *rest = [10, 20, 30, 40]`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 7. Последний элемент
# Используя `*`, получите `head, *middle, tail` из `[1, 2, 3, 4, 5]`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 8. Повторное присваивание
# Сделайте `x, y = 'A', 'B'` затем `x, y = y, x`. Выведите результат.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 9. Unpack tuple
# Распакуйте `(1, 2, 3)` в три переменные и выведите их.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 10. Unpack string
# Распакуйте строку `'Hi!'` в три переменные.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 11. Unpack list
# Создайте список `nums = [1, 2, 3]` и распакуйте его в `x, y, z`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 12. One to all
# Назначьте `'Hello'` трём переменным одной строкой.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 13. Расширенная распаковка
# Используйте `*` чтобы получить `a, b, *rest = [1, 2, 3, 4, 5]` и напечатайте `rest`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 14. Разные типы
# Присвойте `x, y, z = 5, 3.2, 'Hi'` и выведите тип каждой переменной.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 15. Множественный swap
# Создайте `a, b, c = 1, 2, 3` и сделайте `a, b, c = c, a, b`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 16. Распаковка с подмножеством
# Распакуйте только первые два значения из `[10, 20, 30, 40]`, игнорируя остальные.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 17. Игнорирование переменных
# Используйте `_` для пропуска значения: `x, _, z = (1, 2, 3)`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 18. Вложенный список
# Распакуйте `[1, [2, 3]]` в `a, (b, c)` и выведите `b`.

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 19. Множественное копирование
# Сделайте `a = b = c = [1, 2]`, добавьте элемент `3` в `a`. Что произойдёт с `b` и `c`?

# %%
# Ваш код здесь

# %% [markdown]
# ### Упражнение 20. Unpack в цикле
# Для списка пар `pairs = [(1, 'a'), (2, 'b'), (3, 'c')]` распакуйте в цикле `for num, char in pairs` и напечатайте их.

# %%
# Ваш код здесь
